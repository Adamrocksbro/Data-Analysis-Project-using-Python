# %% [markdown]
# Michelle Vigdorchik and Adam Abuhasan

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("test.csv")
df
# Out:
#      User_ID Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 0        500  27      Female  Snapchat                         120
# 1        488  21  Non-binary  Snapchat                          60
# 2        776  28  Non-binary  Snapchat                         115
# 3        869  27        Male  Telegram                         105
# 4        573  21  Non-binary  Facebook                          55
# ..       ...  ..         ...       ...                         ...
# 98       184  22        Male   Twitter                          70
# 99       896  33        Male  LinkedIn                          85
# 100      708  24  Non-binary  Facebook                         110
# 101      993  24        Male  Telegram                          75
# 102       60  27        Male  Facebook                          60
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0                4                      40                         18
# ...

# %% [markdown]
# What social media platforms have the most data usage time out of those over 90 minutes?

# %%
snap = df[df["Platform"] == "Snapchat"]
li = snap["Daily_Usage_Time (minutes)"]
count = 0
for i in li:
    if i > 90:
        count += 1
print(f"How Many Users used Snapchat over 90 minutes: {count}")

telegs = df[df["Platform"] == "Telegram"]
lim = telegs["Daily_Usage_Time (minutes)"]
count = 0
for i in lim:
    if i > 90:
        count += 1
print(f"How Many Users used Telegram over 90 minutes: {count}")

twitter = df[df["Platform"] == "Twitter"]
lims = twitter["Daily_Usage_Time (minutes)"]
count = 0
for i in lims:
    if i > 90:
        count += 1
print(f"How Many Users used Twitter over 90 minutes: {count}")

insta = df[df["Platform"] == "Instagram"]
limss = insta["Daily_Usage_Time (minutes)"]
count = 0
for i in limss:
    if i > 90:
        count += 1
print(f"How Many Users used Instagram over 90 minutes: {count}")

whats = df[df["Platform"] == "Whatsapp"]
limz = whats["Daily_Usage_Time (minutes)"]
count = 0
for i in limz:
    if i > 90:
        count += 1
print(f"How Many Users used Whatsapp over 90 minutes: {count}")

link = df[df["Platform"] == "Linkedin"]
limzz = link["Daily_Usage_Time (minutes)"]
count = 0
for i in limzz:
    if i > 90:
        count += 1
print(f"How Many Users used Linkedin over 90 minutes: {count}")

face = df[df["Platform"] == "Facebook"]
lis = face["Daily_Usage_Time (minutes)"]
count = 0
for i in lis:
    if i > 90:
        count += 1
print(f"How Many Users used Facebook over 90 minutes: {count}")
# Out:
# How Many Users used snapchat over 90 minutes: 8
# How Many Users used Telegram over 90 minutes: 2
# How Many Users used Twitter over 90 minutes: 4
# How Many Users used Instagram over 90 minutes: 16
# How Many Users used Whatsapp over 90 minutes: 1
# How Many Users used Linkedin over 90 minutes: 0
# How Many Users used Facebook over 90 minutes: 5

# %% [markdown]
# We asked our first question on what social media platforms have the most data usage time out of those that are averaging over 90 minutes. We asked the program to generate the number of users in each platform (Snapchat, Telegram, Twitter, Instagram, Whatsapp, Linkedin and Facebook) that average over 90 minutes, inserted the count of users into each platform's own variable and finally outputted the data for comparison. We were able to see that the platform with the most data usage over 90 minutes was Instagram, coming in at 16 users, in comparison to the other ones which were a single digit amount of users. This code outputs numbers for comparison.

# %% [markdown]
# On average, which social media platform has the most users posting more than 4 posts a day and which social media platform has users posting less than 4 posts a day?

# %%
snap = df[df["Platform"] == "Snapchat"]
li = snap["Posts_Per_Day"]
count = {"1-4 posts": 0, "4-8 posts": 0}

for i in li:
    if 1 <= i <= 4:
        count["1-4 posts"] += 1
    elif 4 < i <= 8:
        count["4-8 posts"] += 1

print(f"Snapchat users with 1-4 posts per day: {count['1-4 posts']}")
print(f"Snapchat users with 4-8 posts per day: {count['4-8 posts']}")


telegs = df[df["Platform"] == "Telegram"]
lim = telegs["Posts_Per_Day"]
count = {"1-4 posts": 0, "4-8 posts": 0}
for i in lim:
    if 1 <= i <= 4:
        count["1-4 posts"] += 1
    elif 4 < i <= 8:
        count["4-8 posts"] += 1
print(f"Telegram users with 1-4 posts per day: {count['1-4 posts']}")
print(f"Telegram users with 4-8 posts per day: {count['4-8 posts']}")

twitter = df[df["Platform"] == "Twitter"]
lims = twitter["Posts_Per_Day"]
count = {"1-4 posts": 0, "4-8 posts": 0}
for i in lims:
    if 1 <= i <= 4:
        count["1-4 posts"] += 1
    elif 4 < i <= 8:
        count["4-8 posts"] += 1
print(f"Twitter users with 1-4 posts per day: {count['1-4 posts']}")
print(f"Twitter users with 4-8 posts per day: {count['4-8 posts']}")

insta = df[df["Platform"] == "Instagram"]
limss = insta["Posts_Per_Day"]
count = {"1-4 posts": 0, "4-8 posts": 0}
for i in limss:
    if 1 <= i <= 4:
        count["1-4 posts"] += 1
    elif 4 < i <= 8:
        count["4-8 posts"] += 1
print(f"Instagram users with 1-4 posts per day: {count['1-4 posts']}")
print(f"Instagram users with 4-8 posts per day: {count['4-8 posts']}")

whats = df[df["Platform"] == "Whatsapp"]
limz = whats["Posts_Per_Day"]
count = {"1-4 posts": 0, "4-8 posts": 0}
for i in limz:
    if 1 <= i <= 4:
        count["1-4 posts"] += 1
    elif 4 < i <= 8:
        count["4-8 posts"] += 1
print(f"Whatsapp users with 1-4 posts per day: {count['1-4 posts']}")
print(f"Whatsapp users with 4-8 posts per day: {count['4-8 posts']}")

link = df[df["Platform"] == "Linkedin"]
limzz = link["Posts_Per_Day"]
count = {"1-4 posts": 0, "4-8 posts": 0}
for i in limzz:
    if 1 <= i <= 4:
        count["1-4 posts"] += 1
    elif 4 < i <= 8:
        count["4-8 posts"] += 1
print(f"Linkedin users with 1-4 posts per day: {count['1-4 posts']}")
print(f"Linkedin users with 4-8 posts per day: {count['4-8 posts']}")

face = df[df["Platform"] == "Facebook"]
lis = face["Posts_Per_Day"]
count = {"1-4 posts": 0, "4-8 posts": 0}
for i in lis:
    if 1 <= i <= 4:
        count["1-4 posts"] += 1
    elif 4 < i <= 8:
        count["4-8 posts"] += 1
print(f"Facebook users with 1-4 posts per day: {count['1-4 posts']}")
print(f"Facebook users with 4-8 posts per day: {count['4-8 posts']}")
# Out:
# Snapchat users with 1-4 posts per day: 13
# Snapchat users with 4-8 posts per day: 0
# Telegram users with 1-4 posts per day: 11
# Telegram users with 4-8 posts per day: 0
# Twitter users with 1-4 posts per day: 18
# Twitter users with 4-8 posts per day: 1
# Instagram users with 1-4 posts per day: 0
# Instagram users with 4-8 posts per day: 16
# Whatsapp users with 1-4 posts per day: 4
# Whatsapp users with 4-8 posts per day: 0
# Linkedin users with 1-4 posts per day: 0
# Linkedin users with 4-8 posts per day: 0
# Facebook users with 1-4 posts per day: 24
# Facebook users with 4-8 posts per day: 1

# %% [markdown]
# We asked the program to go through our dataframe and generate the number of users that post 1-4 posts per day and 4-8 posts per day in each social media platform and added each to a count for each platform, then returned each one. We did this so that we could which social media platform had the most users posting more than 4 posts a day and which social media platform had users posting less than 4 posts a day to compare each one. The output we received allowed us to see that Instagram had the most users (16) posting 4-8 posts a day and that Facebook had the most users (24) posting less than 4 posts a day.

# %%
Which social media platform had the dominant emotion of anxiety appearing the most?

# %%
snap = df[df["Platform"] == "Snapchat"]
li = snap["Dominant_Emotion"]
count = 0
for i in li:
    if i == "Anxiety":
        count += 1
print(f"How Many Users felt anxiety using Snapchat: {count}")

telegs = df[df["Platform"] == "Telegram"]
lim = telegs["Dominant_Emotion"]
count = 0
for i in lim:
    if i == "Anxiety":
        count += 1
print(f"How Many Users felt anxiety using Telegram: {count}")

twitter = df[df["Platform"] == "Twitter"]
lims = Twitter["Dominant_Emotion"]
count = 0
for i in lims:
    if i == "Anxiety":
        count += 1
print(f"How Many Users felt anxiety using Twitter: {count}")

insta = df[df["Platform"] == "Instagram"]
limss = insta["Dominant_Emotion"]
count = 0
for i in limss:
    if i == "Anxiety":
        count += 1
print(f"How Many Users felt anxiety using Instagram: {count}")

whats = df[df["Platform"] == "Whatsapp"]
limz = whats["Dominant_Emotion"]
count = 0
for i in limz:
    if i == "Anxiety":
        count += 1
print(f"How Many Users felt anxiety using Whatsapp: {count}")

link = df[df["Platform"] == "Linkedin"]
limzz = link["Dominant_Emotion"]
count = 0
for i in limzz:
    if i == "Anxiety":
        count += 1
print(f"How Many Users felt anxiety using Linkedin: {count}")

face = df[df["Platform"] == "Facebook"]
lis = face["Dominant_Emotion"]
count = 0
for i in lis:
    if i == "Anxiety":
        count += 1
print(f"How Many Users felt anxiety using Facebook: {count}")
# Out:
# How Many Users felt anxiety using Snapchat: 4
# How Many Users felt anxiety using Telegram: 2
# How Many Users felt anxiety using Twitter: 5
# How Many Users felt anxiety using Instagram: 1
# How Many Users felt anxiety using Whatsapp: 1
# How Many Users felt anxiety using Linkedin: 0
# How Many Users felt anxiety using Facebook: 5

# %% [markdown]
# For this question, we wanted to see which social media platform had the dominant emotion of anxiety appearing the most. We did this by having the program generate the number of users within each social media platform that presented Anxiety as their most dominant emotion, and then outputted it for comparison with the others, also by generating a count and outputting it. We were able to see that Twitter and Facebook both had the same number of users (within this dataset) that felt anxiety over any other emotion. This leads us to believe that both Facebook and Twitter may be correlated to anxiety-induction.

# %% [markdown]
# Compare amount of likes based on gender of all social medias in plots (3).

# %%
snap = df[(df["Platform"] == "Snapchat") & ((df["Gender"] == "Female") | (df["Gender"] == "Male") | (df["Gender"] == "Non-binary"))]
likes = snap["Likes_Received_Per_Day"].values
gender = snap["Gender"].values
snap_female = 0
snap_male = 0
snap_nb = 0
for i in range(len(likes)):
    if gender[i] == "Female":
        snap_female += likes[i]
    elif gender[i] == "Male":
        snap_male += likes[i]
    elif gender[i] == "Non-binary":
        snap_nb += likes[i]
        
telegs = df[(df["Platform"] == "Telegram") & ((df["Gender"] == "Female") | (df["Gender"] == "Male") | (df["Gender"] == "Non-binary"))]
likes = telegs["Likes_Received_Per_Day"].values
gender = telegs["Gender"].values
teleg_female = 0
teleg_male = 0
teleg_nb = 0
for i in range(len(likes)):
    if gender[i] == "Female":
        teleg_female += likes[i]
    elif gender[i] == "Male":
        teleg_male += likes[i]
    elif gender[i] == "Non-binary":
        teleg_nb += likes[i]


twitter = df[(df["Platform"] == "Twitter") & ((df["Gender"] == "Female") | (df["Gender"] == "Male") | (df["Gender"] == "Non-binary"))]
likes = twitter["Likes_Received_Per_Day"].values
gender = twitter["Gender"].values
twitter_female = 0
twitter_male = 0
twitter_nb = 0
for i in range(len(likes)):
    if gender[i] == "Female":
        twitter_female += likes[i]
    elif gender[i] == "Male":
        twitter_male += likes[i]
    elif gender[i] == "Non-binary":
        twitter_nb += likes[i]

        
insta = df[(df["Platform"] == "Instagram") & ((df["Gender"] == "Female") | (df["Gender"] == "Male") | (df["Gender"] == "Non-binary"))]
likes = insta["Likes_Received_Per_Day"].values
gender = insta["Gender"].values
insta_female = 0
insta_male = 0
insta_nb = 0
for i in range(len(likes)):
    if gender[i] == "Female":
        insta_female += likes[i]
    elif gender[i] == "Male":
        insta_male += likes[i]
    elif gender[i] == "Non-binary":
        insta_nb += likes[i]


whats = df[(df["Platform"] == "Whatsapp") & ((df["Gender"] == "Female") | (df["Gender"] == "Male") | (df["Gender"] == "Non-binary"))]
likes = whats["Likes_Received_Per_Day"].values
gender = whats["Gender"].values
whats_female = 0
whats_male = 0
whats_nb = 0
for i in range(len(likes)):
    if gender[i] == "Female":
        whats_female += likes[i]
    elif gender[i] == "Male":
        whats_male += likes[i]
    elif gender[i] == "Non-binary":
        whats_nb += likes[i]


link = df[(df["Platform"] == "Linkedin") & ((df["Gender"] == "Female") | (df["Gender"] == "Male") | (df["Gender"] == "Non-binary"))]
likes = link["Likes_Received_Per_Day"].values
gender = link["Gender"].values
link_female = 0
link_male = 0
link_nb = 0
for i in range(len(likes)):
    if gender[i] == "Female":
        link_female += likes[i]
    elif gender[i] == "Male":
        link_male += likes[i]
    elif gender[i] == "Non-binary":
        link_nb += likes[i]

face = df[(df["Platform"] == "Facebook") & ((df["Gender"] == "Female") | (df["Gender"] == "Male") | (df["Gender"] == "Non-binary"))]
likes = face["Likes_Received_Per_Day"].values
gender = face["Gender"].values
face_female = 0
face_male = 0
face_nb = 0
for i in range(len(likes)):
    if gender[i] == "Female":
        face_female += likes[i]
    elif gender[i] == "Male":
        face_male += likes[i]
    elif gender[i] == "Non-binary":
        face_nb += likes[i]

import matplotlib.pyplot as plt


platforms = ["Snapchat", "Telegram", "Twitter", "Instagram", "Whatsapp", "Linkedin", "Facebook"]
female_likes = [165, 0, 250, 695, 44, 0, 28]
male_likes = [0, 328, 351, 397, 61, 0, 174]
nb_likes = [239, 18, 27, 0, 0, 0, 296]

plt.figure(figsize=(10, 6))

plt.plot(platforms, female_likes, label='Female', marker='o', color='pink')
plt.plot(platforms, male_likes, label='Male', marker='o', color='blue')
plt.plot(platforms, nb_likes, label='Non-binary', marker='o', color='purple')

plt.xlabel('Platforms')
plt.ylabel('Total Likes')
plt.title('Likes Received Per Day by Gender on Different Platforms')
plt.legend()


plt.show()

# %% [markdown]
# This particular question was designed so that we would be able to visualize and compare the difference in all three genders when it comes to total number of likes received per day across different social media platforms. We sourced three different categories of data - likes, gender and platforms and gathered the data from the file by pulling values and inserting numbers of likes into a count for each gender category. Then we put them all in a plot so that we would be able to see trends. In terms of comparison of gender - we can definitely tell that on Instagram, females were incredibly more likely to have more likes in comparison to males and also in comparison to other social media platforms. We can also tell that those that are non-binary within this dataframe have gotten the least amount of likes on most apps except for Snapchat. Males received the most of their likes on Instagram, but still coming in far below the women's category. In terms of social media - we can also tell that Instagram is the most used for males and females, not so much non-binary and the least used for male and female was Telegram or Linkedin.  In terms of likes, women tended to get higher likes only in one category, and the male category overtook the others, for the most part.
